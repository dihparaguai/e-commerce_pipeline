# %% [markdown]
# # Análise Exploratória de Dados: devolucoes.csv

# %%
import sys
from pathlib import Path

# Diretório raiz do projeto
PROJ_DIR = str(Path.cwd().parent.parent)

import pandas as pd
import os

# Caminho para o arquivo CSV de devoluções
csv_path = f'{PROJ_DIR}/data/raw/devolucoes/devolucoes.csv'
df_devolucoes = pd.read_csv(csv_path)

# Exibir as primeiras linhas
df_devolucoes.head()

# %%
# Informações sobre tipos de dados e valores nulos
df_devolucoes.info()

# %%
# Estatísticas descritivas
df_devolucoes.describe()

# %%
# Verificação de valores ausentes
df_devolucoes.isnull().sum()

# %%
# Valores duplicados por coluna
df_devolucoes.apply(lambda col: col.duplicated().sum())

# %%
# Distribuição de devoluções por motivo_devolucao
df_devolucoes['motivo_devolucao'].value_counts()
