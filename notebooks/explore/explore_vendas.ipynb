# %% [markdown]
# # Análise Exploratória de Dados: vendas.csv

# %%
import pandas as pd
import os

# Caminho para o arquivo CSV de vendas
csv_path = '../../data/raw/vendas.csv'
df_vendas = pd.read_csv(csv_path)

# Exibir as primeiras linhas
df_vendas.head()

# %%
# Informações sobre tipos de dados e valores nulos
df_vendas.info()

# %%
# Estatísticas descritivas
df_vendas.describe()

# %%
# Verificação de valores ausentes
df_vendas.isnull().sum()

# %%
# Distribuição de vendas por categoria
df_vendas['categoria'].value_counts()

# %%
# Distribuição de vendas por marca
df_vendas['marca'].value_counts()

# %%
# Distribuição de vendas por canal_venda
df_vendas['canal_venda'].value_counts()

# %%
# Distribuição de vendas por forma_pagamento
df_vendas['forma_pagamento'].value_counts()

# %%
# Distribuição de vendas por estado
df_vendas['estado'].value_counts()

# %%
# Distribuição de vendas por status_pedido
df_vendas['status_pedido'].value_counts()
