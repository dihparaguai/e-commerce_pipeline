# %% [markdown]
# # Análise Exploratória de Dados: estoque.csv

# %%
import pandas as pd
import os

# Caminho para o arquivo CSV de estoque
csv_path = '../../data/raw/estoque.csv'
df_estoque = pd.read_csv(csv_path)

# Exibir as primeiras linhas
df_estoque.head()

# %%
# Informações sobre tipos de dados e valores nulos
df_estoque.info()

# %%
# Estatísticas descritivas
df_estoque.describe()

# %%
# Verificação de valores ausentes
df_estoque.isnull().sum()

# %%
# Distribuição de estoque por centro_distribuicao
df_estoque['centro_distribuicao'].value_counts()
